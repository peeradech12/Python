# %%
one = int(input("Enter integer : "))
thou = one //1000
hun = one %1000//100
ten = one %100//10
n = one%10
print(thou)
print(hun)
print(ten)
print(n)
# Out:
# Enter integer : 1234
# 1
# 2
# 3
# 4

# %%
)
