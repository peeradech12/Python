# %%
graph = {
'0' : ['1'],
'1' : ['0','2','3'],
'2' : ['1','3'],
'3' : ['2','1'],
'4' : ['3'],
'5' : [],
'6' : ['7','8'],
'7' : ['6'],
'8' : ['6'],
}
for i in graph:
  print(i, end = " ")
# Out:
# 0 1 2 3 4 5 6 7 8
